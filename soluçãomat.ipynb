# %% [markdown]
# # **Analise precisa entre classes de escola do Ensino Médio:**
#
# ## **Notas, médias e desempenho dos alunos.**
#
# ### *Miguel Fiaschi.*

# %% [markdown]
# # Desempenho turmas:

# %% [markdown]
# ### Alunos com desempenho abaixo de 6:

# %% [markdown]
# ## - 1A:

# %%
# ler a tabela 
import pandas as pd 
import matplotlib.pyplot as plt

tabela_1A = pd.read_csv("notas_matematica1A.csv")
display(tabela_1A)
# Out:
#    Turma             Aluno  Nota_Matemática
# 0    1ºA      Igor Moreira              3.4
# 1    1ºA       Sofia Silva              6.2
# 2    1ºA   Igor Nascimento              9.2
# 3    1ºA   Eduardo Almeida              4.8
# 4    1ºA  Nicolas Oliveira              6.2
# 5    1ºA    Rafael Pereira              7.6
# 6    1ºA      Olívia Gomes              9.4
# 7    1ºA  Fernanda Almeida              7.5
# 8    1ºA  Fernanda Esteves              5.3
# 9    1ºA   Juliana Moreira              2.1
# 10   1ºA     Igor Henrique              3.7
# 11   1ºA    Eduardo Vieira              9.6
# 12   1ºA        Paulo Lima              2.4
# 13   1ºA        Paulo Lima              3.0
# 14   1ºA    Olívia Almeida              5.2
# 15   1ºA   Nicolas Almeida              6.9
# 16   1ºA    Daniela Vieira              4.8
# 17   1ºA    Bruno Henrique              4.9
# 18   1ºA  Daniela Oliveira              5.0
# 19   1ºA    Fernanda Gomes              7.1
# ...

# %%
# identificar aluno com baixo desempenho (notas abaixo de 6)

notas_baixas_1A = tabela_1A[tabela_1A["Nota_Matemática"] < 6]
print("Alunos com notas abaixo de 6:")
print(notas_baixas_1A)
# Out:
# Alunos com notas abaixo de 6:
#    Turma             Aluno  Nota_Matemática
# 0    1ºA      Igor Moreira              3.4
# 3    1ºA   Eduardo Almeida              4.8
# 8    1ºA  Fernanda Esteves              5.3
# 9    1ºA   Juliana Moreira              2.1
# 10   1ºA     Igor Henrique              3.7
# 12   1ºA        Paulo Lima              2.4
# 13   1ºA        Paulo Lima              3.0
# 14   1ºA    Olívia Almeida              5.2
# 16   1ºA    Daniela Vieira              4.8
# 17   1ºA    Bruno Henrique              4.9
# 18   1ºA  Daniela Oliveira              5.0
# 22   1ºA     Paulo Moreira              4.3
# 28   1ºA   Gabriel Moreira              5.9
# 29   1ºA   Helena Henrique              5.0
# 30   1ºA    Sofia Henrique              3.5
# 31   1ºA      Carlos Gomes              1.1
# 37   1ºA     Gabriel Silva              5.9

# %% [markdown]
# ## - 1B:

# %%
tabela_1B = pd.read_csv("notas_matematica1B.csv")
display(tabela_1B)
# Out:
#    Turma               Aluno  Nota_Matemática
# 0    1ºB        Daniela Lima              6.0
# 1    1ºB         Carlos Lima              2.6
# 2    1ºB      Lucas Ferreira              9.4
# 3    1ºB        Nicolas Lima              5.6
# 4    1ºB     Helena Henrique              6.2
# 5    1ºB        Juliana Dias              6.6
# 6    1ºB     Thiago Teixeira              5.1
# 7    1ºB     Juliana Moreira              5.6
# 8    1ºB      Thiago Barbosa              6.0
# 9    1ºB        Vitória Dias              6.6
# 10   1ºB   Fernanda Teixeira              8.3
# 11   1ºB       Paulo Almeida              2.2
# 12   1ºB     Mariana Pereira              3.8
# 13   1ºB    Juliana Oliveira              6.2
# 14   1ºB       Mariana Ramos              9.0
# 15   1ºB       Bruno Barbosa              6.8
# 16   1ºB         Sofia Jesus              2.3
# 17   1ºB        Gabriel Dias              6.0
# 18   1ºB    Fernanda Barbosa              9.3
# ...

# %%
# desempanho alunos 1B

notas_baixas_1B = tabela_1B[tabela_1B["Nota_Matemática"] < 6]
print("Alunos com notas abaixo de 6:")
print(notas_baixas_1B)
# Out:
# Alunos com notas abaixo de 6:
#    Turma             Aluno  Nota_Matemática
# 1    1ºB       Carlos Lima              2.6
# 3    1ºB      Nicolas Lima              5.6
# 6    1ºB   Thiago Teixeira              5.1
# 7    1ºB   Juliana Moreira              5.6
# 11   1ºB     Paulo Almeida              2.2
# 12   1ºB   Mariana Pereira              3.8
# 16   1ºB       Sofia Jesus              2.3
# 21   1ºB     Vitória Silva              5.5
# 22   1ºB     Carlos Igreja              2.0
# 30   1ºB  Juliana Oliveira              3.4
# 31   1ºB     Thiago Vieira              5.8
# 32   1ºB      Igor Almeida              3.4
# 33   1ºB  Sofia Nascimento              5.0
# 36   1ºB   Gabriel Cardoso              4.9
# 38   1ºB      Eduardo Lima              3.6

# %% [markdown]
# # - 2A:

# %%
tabela_2A = pd.read_csv("notas_matematica2A.csv")
display(tabela_2A)
# Out:
#    Turma              Aluno  Nota_Matemática
# 0    2ºA     Gabriel Igreja              7.5
# 1    2ºA     Thiago Cardoso              3.6
# 2    2ºA   Eduardo Henrique              6.9
# 3    2ºA        Bruno Gomes              4.5
# 4    2ºA  Fernanda Henrique              4.8
# 5    2ºA      Paulo Moreira              4.3
# 6    2ºA      Quésia Vieira              8.8
# 7    2ºA  Carlos Nascimento              7.5
# 8    2ºA   Fernanda Queiroz              5.3
# 9    2ºA      Rafael Igreja              6.0
# 10   2ºA   Fernanda Cardoso              6.8
# 11   2ºA        Thiago Lima              7.5
# 12   2ºA      Lucas Esteves             10.0
# 13   2ºA     Thiago Pereira              6.6
# 14   2ºA      Helena Vieira              3.1
# 15   2ºA       Ana Teixeira              8.6
# 16   2ºA   Juliana Henrique              7.0
# 17   2ºA      Lucas Barbosa              5.2
# 18   2ºA    Quésia Ferreira              2.5
# 19   2ºA     Nicolas Igreja              8.5
# ...

# %%
# notas abaixo de 6:

notas_abaixo_2A = tabela_2A[tabela_2A["Nota_Matemática"] < 6]
print("Alunos com notas abaixo de 6:")
print(notas_abaixo_2A)
# Out:
# Alunos com notas abaixo de 6:
#    Turma              Aluno  Nota_Matemática
# 1    2ºA     Thiago Cardoso              3.6
# 3    2ºA        Bruno Gomes              4.5
# 4    2ºA  Fernanda Henrique              4.8
# 5    2ºA      Paulo Moreira              4.3
# 8    2ºA   Fernanda Queiroz              5.3
# 14   2ºA      Helena Vieira              3.1
# 17   2ºA      Lucas Barbosa              5.2
# 18   2ºA    Quésia Ferreira              2.5
# 21   2ºA      Gabriel Silva              5.1
# 22   2ºA     Vitória Igreja              4.2
# 23   2ºA     Quésia Esteves              5.7
# 24   2ºA    Daniela Moreira              3.9
# 27   2ºA      Thiago Igreja              3.9
# 28   2ºA    Gabriel Barbosa              5.4
# 30   2ºA       Paulo Vieira              4.1
# 31   2ºA   Eduardo Teixeira              5.1

# %% [markdown]
# # - 2B:

# %%
tabela_2B = pd.read_csv("notas_matematica2B.csv")
display(tabela_2B)
# Out:
#    Turma               Aluno  Nota_Matemática
# 0    2ºB        Daniela Lima              7.1
# 1    2ºB        Carlos Silva              4.1
# 2    2ºB       Eduardo Ramos              5.0
# 3    2ºB    Vitória Ferreira              5.3
# 4    2ºB    Vitória Henrique              4.1
# 5    2ºB     Daniela Pereira             10.0
# 6    2ºB         Rafael Dias              5.2
# 7    2ºB     Mariana Cardoso              4.4
# 8    2ºB     Carlos Teixeira              4.7
# 9    2ºB         Sofia Silva              6.0
# 10   2ºB        Mariana Dias              8.2
# 11   2ºB      Lucas Teixeira              5.5
# 12   2ºB         Olívia Dias              4.6
# 13   2ºB   Quésia Nascimento              6.9
# 14   2ºB        Rafael Jesus              9.4
# 15   2ºB         Bruno Silva              5.7
# 16   2ºB       Eduardo Gomes              5.0
# 17   2ºB      Fernanda Silva              7.6
# 18   2ºB        Vitória Dias              6.3
# ...

# %%
# desempanho dos alunos:

notas_abaixo_2B = tabela_2B[tabela_2B["Nota_Matemática"] < 6]
print("Alunos com notas abaixo de 6:")
print(notas_abaixo_2B)
# Out:
# Alunos com notas abaixo de 6:
#    Turma             Aluno  Nota_Matemática
# 1    2ºB      Carlos Silva              4.1
# 2    2ºB     Eduardo Ramos              5.0
# 3    2ºB  Vitória Ferreira              5.3
# 4    2ºB  Vitória Henrique              4.1
# 6    2ºB       Rafael Dias              5.2
# 7    2ºB   Mariana Cardoso              4.4
# 8    2ºB   Carlos Teixeira              4.7
# 11   2ºB    Lucas Teixeira              5.5
# 12   2ºB       Olívia Dias              4.6
# 15   2ºB       Bruno Silva              5.7
# 16   2ºB     Eduardo Gomes              5.0
# 21   2ºB       Rafael Lima              5.1
# 22   2ºB     Bruno Almeida              3.3
# 24   2ºB      Bruno Vieira              5.9
# 27   2ºB     Quésia Vieira              4.5
# 28   2ºB      Quésia Ramos              4.3
# 29   2ºB   Quésia Teixeira              2.3
# 32   2ºB      Quésia Gomes              3.8
# 34   2ºB     Carlos Vieira              3.5
# 36   2ºB     Bruno Moreira              5.7
# ...

# %% [markdown]
# # - 2C:

# %%
tabela_2C = pd.read_csv("notas_matematica2C.csv")
display(tabela_2C)
# Out:
#    Turma               Aluno  Nota_Matemática
# 0    2ºC        Vitória Dias              5.1
# 1    2ºC     Gabriel Almeida              8.0
# 2    2ºC        Thiago Silva              5.3
# 3    2ºC       Eduardo Gomes              7.8
# 4    2ºC          Igor Gomes              4.6
# 5    2ºC  Gabriel Nascimento              7.7
# 6    2ºC       Sofia Queiroz              8.9
# 7    2ºC    Gabriel Ferreira              3.6
# 8    2ºC       Lucas Almeida              4.8
# 9    2ºC       Lucas Moreira             10.0
# 10   2ºC            Ana Lima              5.0
# 11   2ºC        Ana Ferreira              5.6
# 12   2ºC     Juliana Barbosa              7.8
# 13   2ºC         Helena Lima              7.0
# 14   2ºC        Quésia Jesus              5.0
# 15   2ºC       Olívia Igreja              4.1
# 16   2ºC     Eduardo Moreira              5.7
# 17   2ºC        Thiago Silva              5.0
# 18   2ºC       Mariana Jesus              5.2
# ...

# %%
# desempenho alunos 2C:
 
notas_abaixo_2C = tabela_2C[tabela_2C["Nota_Matemática"] < 6] 
print("Alunos com notas abaixo de 6:")      
print(notas_abaixo_2C)
# Out:
# Alunos com notas abaixo de 6:
#    Turma             Aluno  Nota_Matemática
# 0    2ºC      Vitória Dias              5.1
# 2    2ºC      Thiago Silva              5.3
# 4    2ºC        Igor Gomes              4.6
# 7    2ºC  Gabriel Ferreira              3.6
# 8    2ºC     Lucas Almeida              4.8
# 10   2ºC          Ana Lima              5.0
# 11   2ºC      Ana Ferreira              5.6
# 14   2ºC      Quésia Jesus              5.0
# 15   2ºC     Olívia Igreja              4.1
# 16   2ºC   Eduardo Moreira              5.7
# 17   2ºC      Thiago Silva              5.0
# 18   2ºC     Mariana Jesus              5.2
# 21   2ºC   Fernanda Vieira              5.1
# 22   2ºC   Daniela Pereira              4.8
# 23   2ºC          Ana Dias              4.9
# 30   2ºC       Carlos Dias              5.4
# 34   2ºC   Mariana Barbosa              5.4
# 35   2ºC   Vitória Esteves              3.6
# 36   2ºC    Fernanda Ramos              5.7
# 37   2ºC    Fernanda Silva              4.8
# ...

# %% [markdown]
# # - 3A:

# %%
tabela_3A = pd.read_csv("notas_matematica3A.csv")
display(tabela_3A)
# Out:
#    Turma               Aluno  Nota_Matemática
# 0    3ºA       Juliana Gomes              6.1
# 1    3ºA      Olívia Esteves              7.0
# 2    3ºA       Lucas Pereira              4.5
# 3    3ºA        Olívia Gomes              5.8
# 4    3ºA  Gabriel Nascimento              3.4
# 5    3ºA      Thiago Cardoso              9.1
# 6    3ºA      Fernanda Jesus              9.3
# 7    3ºA      Quésia Moreira              5.6
# 8    3ºA     Nicolas Almeida              3.5
# 9    3ºA    Vitória Teixeira              8.9
# 10   3ºA      Sofia Henrique             10.0
# 11   3ºA       Eduardo Jesus              3.8
# 12   3ºA     Nicolas Almeida              3.0
# 13   3ºA     Nicolas Moreira              7.4
# 14   3ºA      Olívia Queiroz              4.8
# 15   3ºA         Sofia Ramos              1.3
# 16   3ºA      Carlos Pereira              7.5
# 17   3ºA    Lucas Nascimento              4.4
# 18   3ºA        Quésia Silva              6.2
# ...

# %%
# notas abaixo de 6: 

notas_abaixo_3A = tabela_3A[tabela_3A["Nota_Matemática"] < 6]
print("Alunos com notas abaixo de 6:")
print(notas_abaixo_3A)
# Out:
# Alunos com notas abaixo de 6:
#    Turma               Aluno  Nota_Matemática
# 2    3ºA       Lucas Pereira              4.5
# 3    3ºA        Olívia Gomes              5.8
# 4    3ºA  Gabriel Nascimento              3.4
# 7    3ºA      Quésia Moreira              5.6
# 8    3ºA     Nicolas Almeida              3.5
# 11   3ºA       Eduardo Jesus              3.8
# 12   3ºA     Nicolas Almeida              3.0
# 14   3ºA      Olívia Queiroz              4.8
# 15   3ºA         Sofia Ramos              1.3
# 17   3ºA    Lucas Nascimento              4.4
# 20   3ºA      Nicolas Vieira              5.9
# 24   3ºA    Paulo Nascimento              5.1
# 27   3ºA    Daniela Oliveira              3.9
# 30   3ºA        Rafael Silva              5.3

# %% [markdown]
# # - 3B:

# %%
tabela_3B = pd.read_csv("notas_matematica3B.csv")
display(tabela_3B)
# Out:
#    Turma               Aluno  Nota_Matemática
# 0    3ºB       Thiago Igreja             10.0
# 1    3ºB       Bruno Queiroz              5.9
# 2    3ºB  Daniela Nascimento              4.1
# 3    3ºB         Olívia Dias              5.9
# 4    3ºB    Fernanda Barbosa              7.6
# 5    3ºB       Igor Ferreira              3.8
# 6    3ºB       Mariana Gomes              9.9
# 7    3ºB       Bruno Moreira              4.2
# 8    3ºB           Ana Ramos              5.1
# 9    3ºB            Ana Dias              3.0
# 10   3ºB      Vitória Vieira              6.3
# 11   3ºB     Olívia Henrique              8.2
# 12   3ºB     Juliana Pereira              5.1
# 13   3ºB     Eduardo Pereira              7.8
# 14   3ºB      Sofia Henrique              6.4
# 15   3ºB       Sofia Cardoso              5.5
# 16   3ºB      Olívia Queiroz              4.2
# 17   3ºB        Igor Almeida              7.2
# 18   3ºB     Thiago Teixeira              5.8
# ...

# %%
# desempenho alunos 3A:
notas_abaixo_3B = tabela_3B[tabela_3B["Nota_Matemática"] < 6]
print("Alunos com notas abaixo de 6:")
print(notas_abaixo_3B)
# Out:
# Alunos com notas abaixo de 6:
#    Turma               Aluno  Nota_Matemática
# 1    3ºB       Bruno Queiroz              5.9
# 2    3ºB  Daniela Nascimento              4.1
# 3    3ºB         Olívia Dias              5.9
# 5    3ºB       Igor Ferreira              3.8
# 7    3ºB       Bruno Moreira              4.2
# 8    3ºB           Ana Ramos              5.1
# 9    3ºB            Ana Dias              3.0
# 12   3ºB     Juliana Pereira              5.1
# 15   3ºB       Sofia Cardoso              5.5
# 16   3ºB      Olívia Queiroz              4.2
# 18   3ºB     Thiago Teixeira              5.8
# 19   3ºB       Nicolas Ramos              3.2
# 21   3ºB        Igor Pereira              5.3
# 23   3ºB           Ana Silva              4.8
# 27   3ºB      Bruno Oliveira              4.4
# 28   3ºB       Helena Igreja              3.5
# 29   3ºB    Mariana Teixeira              5.2
# 30   3ºB   Fernanda Oliveira              4.1
# 33   3ºB       Lucas Pereira              4.6

# %% [markdown]
# # Média das turmas (comparação):

# %% [markdown]
# # - 1A:

# %%
# média 1a:
média_1A = tabela_1A["Nota_Matemática"].mean().round(1)
print("Média da turma 1A:", média_1A)
# Out:
# Média da turma 1A: 6.2

# %% [markdown]
# # - 1B:

# %%
# média 1b:
média_1B = tabela_1B["Nota_Matemática"].mean().round(1)
print("Média da turma 1B:", média_1B)
# Out:
# Média da turma 1B: 6.2

# %% [markdown]
# # - 2A:

# %%
# média 2a:
média_2A = tabela_2A["Nota_Matemática"].mean().round(1)
print("Média da turma 2A:", média_2A)
# Out:
# Média da turma 2A: 6.0

# %% [markdown]
# # - 2B:

# %%
# média 2b:
média_2B = tabela_2B["Nota_Matemática"].mean().round(1)
print("Média da turma 2B:", média_2B)
# Out:
# Média da turma 2B: 6.3

# %% [markdown]
# # - 2C:

# %%
# média 2c: 
média_2C = tabela_2C["Nota_Matemática"].mean().round(1)
print("Média da turma 2C:", média_2C)
# Out:
# Média da turma 2C: 6.5

# %% [markdown]
# # - 3A:

# %%
# média 3a:
média_3A = tabela_3A["Nota_Matemática"].mean().round(1)
print("Média da turma 3A:", média_3A)
# Out:
# Média da turma 3A: 6.2

# %% [markdown]
# # - 3B:

# %%
# média 3b:
média_3B = tabela_3B["Nota_Matemática"].mean().round(1)
print("Média da turma 3B:", média_3B)
# Out:
# Média da turma 3B: 6.2

# %%
# média entre elas: 

média_entre_as_turmas = ((média_1A + média_1B + média_2A + média_2B + média_2C + média_3A + média_3B) / 7).round(1)
print("Média entre as turmas:", média_entre_as_turmas)
# Out:
# Média entre as turmas: 6.2

# %% [markdown]
# # 5 melhores alunos de cada turma:

# %% [markdown]
# # - 1A:

# %%
# melhores alunos 1a: 
melhores_alunos_1A = tabela_1A.nlargest(5, "Nota_Matemática")
print("Melhores alunos da turma 1A:", melhores_alunos_1A)
# Out:
# Melhores alunos da turma 1A:    Turma            Aluno  Nota_Matemática
# 35   1ºA     Juliana Dias             10.0
# 24   1ºA   Paulo Ferreira              9.9
# 11   1ºA   Eduardo Vieira              9.6
# 6    1ºA     Olívia Gomes              9.4
# 20   1ºA  Nicolas Moreira              9.4

# %% [markdown]
# # - 1B:

# %%
# melhores alunos 1b: 
melhores_alunos_1B = tabela_1B.nlargest(5, "Nota_Matemática")
print("Melhores alunos da turma 1B:", melhores_alunos_1B)
# Out:
# Melhores alunos da turma 1B:    Turma             Aluno  Nota_Matemática
# 2    1ºB    Lucas Ferreira              9.4
# 18   1ºB  Fernanda Barbosa              9.3
# 37   1ºB    Quésia Cardoso              9.1
# 14   1ºB     Mariana Ramos              9.0
# 20   1ºB     Mariana Silva              8.9

# %% [markdown]
# # - 2A:

# %%
# melhores alunos 2a: 
melhores_alunos_2A = tabela_2A.nlargest(5, "Nota_Matemática")
print("Melhores alunos da turma 2A:", melhores_alunos_2A)
# Out:
# Melhores alunos da turma 2A:    Turma              Aluno  Nota_Matemática
# 12   2ºA      Lucas Esteves             10.0
# 6    2ºA      Quésia Vieira              8.8
# 29   2ºA  Olívia Nascimento              8.8
# 15   2ºA       Ana Teixeira              8.6
# 19   2ºA     Nicolas Igreja              8.5

# %% [markdown]
# # - 2B:

# %%
# melhores alunos 2b:
melhores_alunos_2B = tabela_2B.nlargest(5, "Nota_Matemática")
print("Melhores alunos da turma 2B:", melhores_alunos_2B)
# Out:
# Melhores alunos da turma 2B:    Turma               Aluno  Nota_Matemática
# 5    2ºB     Daniela Pereira             10.0
# 46   2ºB       Mariana Silva             10.0
# 39   2ºB      Carlos Moreira              9.9
# 14   2ºB        Rafael Jesus              9.4
# 30   2ºB  Juliana Nascimento              9.3

# %% [markdown]
# # - 2C:

# %%
# melhores alunos 2c:
melhores_alunos_2C = tabela_2C.nlargest(5, "Nota_Matemática")
print("Melhores alunos da turma 2C:", melhores_alunos_2C)
# Out:
# Melhores alunos da turma 2C:    Turma           Aluno  Nota_Matemática
# 9    2ºC   Lucas Moreira             10.0
# 25   2ºC     Carlos Lima             10.0
# 33   2ºC   Juliana Ramos             10.0
# 47   2ºC  Lucas Ferreira             10.0
# 48   2ºC    Juliana Lima              9.7

# %% [markdown]
# # - 3A:

# %%
# melhores alunos 3a:
melhores_alunos_3A = tabela_3A.nlargest(5, "Nota_Matemática")
print("Melhores alunos da turma 3A:", melhores_alunos_3A)
# Out:
# Melhores alunos da turma 3A:    Turma             Aluno  Nota_Matemática
# 10   3ºA    Sofia Henrique             10.0
# 6    3ºA    Fernanda Jesus              9.3
# 5    3ºA    Thiago Cardoso              9.1
# 9    3ºA  Vitória Teixeira              8.9
# 31   3ºA        Igor Ramos              8.3

# %% [markdown]
# # - 3B:

# %%
# melhores alunos 3b:
melhores_alunos_3B = tabela_3B.nlargest(5, "Nota_Matemática")
print("Melhores alunos da turma 3B:", melhores_alunos_3B)
# Out:
# Melhores alunos da turma 3B:    Turma          Aluno  Nota_Matemática
# 0    3ºB  Thiago Igreja             10.0
# 22   3ºB  Helena Igreja             10.0
# 6    3ºB  Mariana Gomes              9.9
# 24   3ºB  Daniela Ramos              9.3
# 26   3ºB   Igor Moreira              8.9

# %% [markdown]
# # Avaliação para a necessidade de reforço:

# %% [markdown]
# # - 1A:

# %%
# saber a porcentagem de alunos que precisam de reforço em cada turma:
porcentagem_reforco_1A = round((len(notas_baixas_1A) / len(tabela_1A)) * 100)
print("Porcentagem de alunos que precisam de reforço na turma 1A:", porcentagem_reforco_1A)
# Out:
# Porcentagem de alunos que precisam de reforço na turma 1A: 42

# %% [markdown]
# # - 1B:

# %%
porcentagem_reforço_1B = round((len(notas_baixas_1B) / len(tabela_1B)) * 100)
print("Porcentagem de alunos que precisam de reforço na turma 1B:", porcentagem_reforço_1B)
# Out:
# Porcentagem de alunos que precisam de reforço na turma 1B: 38

# %% [markdown]
# # - 2A:

# %%
porcentagem_reforço_2A = round((len(notas_abaixo_2A) / len(tabela_2A)) * 100)
print("Porcentagem de alunos que precisam de reforço na turma 2A:", porcentagem_reforço_2A)
# Out:
# Porcentagem de alunos que precisam de reforço na turma 2A: 50

# %% [markdown]
# # - 2B:

# %%
porcentagem_reforço_2B = round((len(notas_abaixo_2B) / len(tabela_2B)) * 100)
print("Porcentagem de alunos que precisam de reforço na turma 2B:", porcentagem_reforço_1B)
# Out:
# Porcentagem de alunos que precisam de reforço na turma 2B: 38

# %% [markdown]
# # - 2C:

# %%
porcentagem_reforço_2C = round((len(notas_abaixo_2C) / len(tabela_2C)) * 100)
print("Porcentagem de alunos que precisam de reforço na turma 2C:", porcentagem_reforço_2C)
# Out:
# Porcentagem de alunos que precisam de reforço na turma 2C: 49

# %% [markdown]
# # - 3A:

# %%
porcentagem_reforço_3A = round((len(notas_abaixo_3A) / len(tabela_3A)) * 100)
print("Porcentagem de alunos que precisam de reforço na turma 3A:", porcentagem_reforço_3A)
# Out:
# Porcentagem de alunos que precisam de reforço na turma 3A: 44

# %% [markdown]
# # - 3B:

# %%
porcentagem_reforço_3B = round((len(notas_abaixo_3B) / len(tabela_3B)) * 100)
print("Porcentagem de alunos que precisam de reforço na turma 3B:", porcentagem_reforço_3B)
# Out:
# Porcentagem de alunos que precisam de reforço na turma 3B: 54

# %%
media_das_turmas = {

"Média 1A": 6.2,
"Média 1B": 6.2,
"Média 2A": 6.0,
"Média 2B": 6.3,
"Média 2C": 6.5,
"Média 3A": 6.2,
"Média 3B": 6.2

}



media_series = pd.Series(media_das_turmas)

# %% [markdown]
# # Gráfico:

# %%
media_series.plot(kind="bar", color=["blue", "red", "green", "yellow", "purple", "orange", "pink" ])

plt.title("Média das Turmas")
plt.xlabel("Turmas")
plt.ylabel("Média das Notas")
plt.ylim(0, 10)
plt.grid(axis="y", linestyle="-", alpha=0.5)
plt.show()
